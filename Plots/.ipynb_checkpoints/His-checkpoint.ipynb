# %%
import numpy as np

from bokeh.plotting import figure, show
import pandas as pd
from bokeh.io import curdoc,output_notebook,export_png
from bokeh.layouts import column,gridplot
from print_versions import print_versions
from sklearn.metrics import r2_score
from seaborn import clustermap
from bokeh.models import Band, ColumnDataSource
import pandas as pd
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"

# %%
PM25=pd.read_excel("../data/Pre_flow_cal.xlsx")

# %%
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ec5175f7-de48-4dd5-9e1d-71280785b1bd">Loading BokehJS ...</span>
#     </div>

# %%
PM25_smoke=PM25.loc[PM25.passive>0]
PM25_nonsmoke=PM25.loc[PM25.passive==0]

# %%
no2=pd.read_excel(r"../data/before_season_correction.xlsx")

# %%
no2_smoke=no2.loc[PM25.passive>0]
no2_nonsmoke=no2.loc[PM25.passive==0]

# %%
no2_smoke
# Out:
#      cpnr  cpnr.1  maalnr  constrution_year   Area  floor_level  powerplant  \
# 0       1       1       1            1979.0  126.0          0.0         0.0
# 1       3       3       1            1924.0   74.0          1.0      4948.3
# 2       5       5       1            1997.0  134.0          0.0         0.0
# 3       7       7       1            1985.0  238.0          0.0         0.0
# 4       8       8       1            1999.0  144.0          0.0         0.0
# ..    ...     ...     ...               ...    ...          ...         ...
# 837   450     450       3            1968.0   94.0          1.0         0.0
# 838     3       3       3            1946.7  120.1          0.5      2420.9
# 839     4       4       3            1963.6  132.4          0.2       131.4
# 840    30      30       3            1954.3  128.9          0.3       749.7
# 841    60      60       3            1957.1  120.4          0.3      1950.1
#
#         road  motorway   forest  ...  visit   no2   nox  formaldehyd  acetald  \
# 0    11223.0    1036.6   1086.6  ...      1   7.8   6.3         18.8      6.5
# 1    21995.1    1176.9   1096.4  ...      1  30.5  64.5         19.4     16.6
# 2    10507.8      82.1  16507.8  ...      1  10.9  11.7         19.9     12.8
# 3    17252.0    3729.0   5828.2  ...      1  10.3  16.4         21.4     16.0
# 4    15371.1      20.2   3992.8  ...      1   7.1   9.4         19.8     13.6
# ..       ...       ...      ...  ...    ...   ...   ...          ...      ...
# 837  20693.9    3318.7   3691.1  ...      3   3.8   4.3         20.9      0.6
# 838  21260.1    2561.7   4560.4  ...      3  17.6  19.0         23.6      6.1
# 839  14727.8    2391.4  12090.4  ...      3   3.6   6.4         42.7     19.5
# 840  16795.7    2019.2   9847.9  ...      3   6.8  27.8         28.0     22.9
# 841  19222.3    2872.0   7731.3  ...      3  16.3  14.6         56.5      8.8
#
#      acetone  sample_time  no2_corrected  formaldehyd_corrected  \
# 0       20.0           75            8.0                   19.4
# 1       26.0           81           32.2                   20.4
# 2       22.1           75           11.2                   20.5
# 3       26.0           59            9.8                   20.5
# 4       25.0           76            7.3                   20.5
# ..       ...          ...            ...                    ...
# 837      0.9           79            4.0                   22.1
# 838      6.5          108           21.3                   29.6
# 839     39.7           84            3.9                   46.4
# 840     24.0           90            7.5                   31.5
# 841      6.9           80           17.1                   60.0
#
#      corrected_week
# 0              15.7
# 1              14.1
# 2               8.7
# 3              15.6
# 4              15.1
# ..              ...
# 837            25.7
# 838             8.0
# 839             8.3
# 840            36.6
# 841            13.0
#
# [367 rows x 29 columns]

# %%
rng = np.random.default_rng()
x = rng.normal(loc=0, scale=1, size=1000)

p = figure(width=500, height=500, toolbar_location=None,
           title="Normal (Gaussian) Distribution")

# Histogram
bins = np.linspace(0, 120, 40)
hist_smoke, edges_smoke = np.histogram(PM25_smoke.pm_final, density=True, bins=bins)
hist, edges = np.histogram(PM25_nonsmoke.pm_final, density=True, bins=bins)

p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
         fill_color="skyblue", line_color="white",
         legend_label="1000 random samples",fill_alpha =0.5)
p.quad(top=hist_smoke, bottom=0, left=edges_smoke[:-1], right=edges_smoke[1:],
         fill_color="red", line_color="white",
         legend_label="1000 random samples",fill_alpha =0.5)
p.y_range.start = 0
p.xaxis.axis_label = "x"
p.yaxis.axis_label = "PDF(x)"
p1 = figure(width=500, height=500, toolbar_location=None,
           title="Normal (Gaussian) Distribution")

# Histogram
bins_no2 = np.linspace(0, 120, 40)
hist_smoke_no2 , edges_smoke_no2  = np.histogram(no2_smoke.no2, density=True, bins=bins)
hist_no2 , edges_no2  = np.histogram(no2_nonsmoke.no2, density=True, bins=bins)

p1.quad(top=hist_no2 , bottom=0, left=edges_no2 [:-1], right=edges_no2 [1:],
         fill_color="skyblue", line_color="white",
         legend_label="1000 random samples",fill_alpha =0.5)
p1.quad(top=hist_smoke_no2 , bottom=0, left=edges_smoke_no2 [:-1], right=edges_smoke_no2 [1:],
         fill_color="red", line_color="white",
         legend_label="1000 random samples",fill_alpha =0.5)
p1.y_range.start = 0
p1.xaxis.axis_label = "x"
p1.yaxis.axis_label = "PDF(x)"
grid =  gridplot([[p, p1]], width=500, height=500);

show(column(grid));
# Out:
#   <div id="e6eeb53b-1d2f-4071-b239-854547d81f4c" data-root-id="p1897" style="display: contents;"></div>
