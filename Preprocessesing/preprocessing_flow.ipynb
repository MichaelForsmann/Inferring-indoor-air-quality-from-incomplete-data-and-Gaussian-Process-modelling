# %%
from sklearn.experimental import enable_iterative_imputer
import pandas as pd
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler
import numpy as np
import kennard_stone as ks

# %%
PM25=pd.read_excel(r"../data/pm_flow.xlsx");

# %%
PM25
# Out:
#       Unnamed: 0      flow   pm_final  sv_final  corrected_week          road  \
# 0              0  4.078578   7.685853  0.188229       10.977601  16527.265027
# 1              1  3.955633  17.020186  1.194621       42.790533  25037.694839
# 2              2  4.250717   8.559098  0.580372       11.080365  18601.170513
# 3              3  3.776065  16.979465  1.471104       50.649244  20296.217445
# 4              4  3.996704  17.269636  0.877552       47.585617  24402.348683
# ...          ...       ...        ...       ...             ...           ...
# 1115        1115  3.949444   9.085729  0.575143       18.878783  13656.446941
# 1116        1116  3.972383   8.551858  0.738417       35.943214  17478.580662
# 1117        1117  3.921155  24.146584  1.395958       44.266324  15150.473078
# 1118        1118  3.971983  12.942080  1.308991       14.874871  13826.059933
# 1119        1119  4.016337  23.232831  1.729992        3.184151  21645.180466
#
#          passive        Area  household
# 0     130.261565  101.413109        284
# 1     366.238931   62.207326        189
# 2     371.249905  122.376528        161
# 3     157.839268  126.505634        383
# 4     361.364271   93.808775        347
# ...          ...         ...        ...
# 1115    0.060687   40.614142        196
# 1116    0.000000  148.858539         58
# 1117  156.571730  108.181318        164
# 1118    0.000000   90.750372        172
# 1119  365.655662  136.959831         18
#
# [1120 rows x 9 columns]

# %%
bnr=PM25.reset_index().loc[:,["household","Area","passive","flow","road"]].groupby("household").mean().reset_index()
X_train, X_test, y_train, y_test = ks.train_test_split(bnr.loc[:,["Area","passive","flow","road"]], bnr.household, test_size = 0.3);
PM25=PM25.set_index("household")
train=PM25.loc[y_train.values,:]
test=PM25.loc[y_test.values,:]
# Out:
# /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-04-24 11:53:04,522 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2025-04-24 11:53:04,523 - kennard_stone.utils._pairwise:109[INFO] - Calculating pairwise distances using scikit-learn.
#
# /data/michaelf/miniconda3/envs/gaussion_process/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
PM25.loc[train.index,"label"]=0
PM25.loc[test.index,"label"]=1

# %%
PM25.to_excel("../data/Pre_flow_cal.xlsx")
